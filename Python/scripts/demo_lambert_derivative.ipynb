# %% [markdown]
# # Test Lambert derivative calculation

# %%
import sys
sys.path.append("../src")
import numpy as np
from lambert_derivatives import lambert_numerical_derivatives, lambert_derivatives
from pykep.core import lambert_problem


def lambert_wrap(r1, r2, t1, t2, mu):
    tof = t2 - t1
    lambert = lambert_problem(r1, r2, tof, mu, False, 0)
    v1 = np.array(lambert.get_v1()[0])
    v2 = np.array(lambert.get_v2()[0])
    return v1, v2

mu = 1
r1 = np.array([-0.66234662571997105, 0.74919751798749190, -1.6259997018919074E-04])
r2 = np.array([-0.24986234273434585, -0.69332384278075210, 4.9599012168662551E-03])
t1 = 0
t2 = 2.5803148345055149
tof = t2 - t1
v1, v2 = lambert_wrap(r1, r2, t1, t2, mu)

print("v1:", v1)
print("v2:", v2)

# compute numerical jacobian
dv_dt_num, dv_dr_num, cat_num = lambert_numerical_derivatives(r1, r2, tof, mu)
dv_dt, dv_dr = lambert_derivatives(r1, v1, r2, v2, tof, mu, debug=True, num_jacob=cat_num)

print('Finished')
# Out:
# v1: [-0.81667468 -0.32961417  0.00624811]
# v2: [ 1.21891795  0.05977451 -0.00710194]
# ID |   value           | numerical             diff
# ----------------------------------------------------------
#  1 |  1.4275266178e-01 | 1.4275266178e-01   (-2.1924e-11)
#  2 | -2.5683817511e-01 | -2.5683817509e-01   (1.0079e-10)
#  3 |  5.2570523572e-04 | 5.2570523568e-04   (7.4485e-11)
#  4 | -1.4275266178e-01 | -1.4275266178e-01   (-2.1924e-11)
#  5 |  2.5683817511e-01 | 2.5683817509e-01   (1.0079e-10)
#  6 | -5.2570523572e-04 | -5.2570523568e-04   (7.4485e-11)
#  7 | -1.2131567709e-02 | -1.2131567728e-02   (-1.5626e-09)
#  8 | -2.8646599209e-01 | -2.8646599207e-01   (5.6658e-11)
#  9 |  1.5414843377e-03 | 1.5414843377e-03   (-5.4760e-11)
# 10 |  1.2131567709e-02 | 1.2131567728e-02   (-1.5626e-09)
# 11 |  2.8646599209e-01 | 2.8646599207e-01   (5.6658e-11)
# 12 | -1.5414843377e-03 | -1.5414843377e-03   (-5.4760e-11)
# 13 | -8.7581965776e-01 | -8.7581965773e-01   (3.2463e-11)
# 14 |  5.9373435675e-01 | 5.9373435676e-01   (-1.6921e-11)
# 15 |  5.9995779047e-03 | 5.9995779234e-03   (-3.1139e-09)
# 16 |  5.9373435675e-01 | 5.9373435674e-01   (2.0478e-11)
# 17 |  2.2675551310e-02 | 2.2675551326e-02   (-6.8123e-10)
# 18 |  4.2494900211e-04 | 4.2494898711e-04   (3.5292e-08)
# 19 |  5.9995779047e-03 | 5.9995779048e-03   (-2.0043e-11)
# 20 |  4.2494900211e-04 | 4.2494900194e-04   (3.8898e-10)
# 21 |  7.4849340208e-01 | 7.4849340204e-01   (4.1317e-11)
# 22 |  1.1464346247e-01 | 1.1464346245e-01   (2.4495e-10)
# 23 |  5.1127505016e-02 | 5.1127505041e-02   (-4.9273e-10)
# 24 |  6.2565606746e-03 | 6.2565606807e-03   (-9.6385e-10)
# 25 | -2.4709546241e-01 | -2.4709546239e-01   (7.9923e-11)
# 26 |  7.4246530945e-01 | 7.4246530944e-01   (1.0966e-11)
# 27 |  4.1648802470e-03 | 4.1648802296e-03   (4.1834e-09)
# 28 |  7.7909114809e-03 | 7.7909114811e-03   (-3.4185e-11)
# 29 |  2.5025470707e-03 | 2.5025470709e-03   (-7.3940e-11)
# 30 |  1.2842068520e+00 | 1.2842068520e+00   (2.3065e-11)
# 31 | -1.1464346247e-01 | -1.1464346248e-01   (-4.5570e-11)
# 32 |  2.4709546241e-01 | 2.4709546240e-01   (1.2527e-11)
# 33 | -7.7909114809e-03 | -7.7909115159e-03   (-4.4985e-09)
# 34 | -5.1127505016e-02 | -5.1127505052e-02   (-7.0988e-10)
# 35 | -7.4246530945e-01 | -7.4246530948e-01   (-4.1370e-11)
# 36 | -2.5025470707e-03 | -2.5025470696e-03   (4.4595e-10)
# 37 | -6.2565606746e-03 | -6.2565606745e-03   (2.0440e-11)
# 38 | -4.1648802470e-03 | -4.1648802467e-03   (8.0742e-11)
# 39 | -1.2842068520e+00 | -1.2842068520e+00   (1.3339e-11)
# 40 |  4.4501264307e-01 | 4.4501264305e-01   (4.2232e-11)
# 41 |  1.1628008100e+00 | 1.1628008101e+00   (-3.2084e-11)
# 42 | -1.6679263381e-02 | -1.6679263348e-02   (1.9685e-09)
# 43 |  1.1628008100e+00 | 1.1628008100e+00   (2.0429e-11)
# 44 |  4.6967289368e-01 | 4.6967289364e-01   (8.5885e-11)
# 45 | -1.6481622762e-02 | -1.6481622789e-02   (-1.6121e-09)
# 46 | -1.6679263381e-02 | -1.6679263381e-02   (-1.7955e-11)
# 47 | -1.6481622762e-02 | -1.6481622763e-02   (-3.3277e-11)
# 48 | -1.4737961686e+00 | -1.4737961685e+00   (6.2422e-11)
# Finished
